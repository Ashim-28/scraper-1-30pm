# %% [markdown]
# a = [1,2,'ashim',True,3,4]
# len(a)
# a[0],a[2],a[5]

# %%
my_info = ['Ashim',20,'5.11ft','not married','Nepal']
print(my_info)
# Out:
# ['Ashim', 20, '5.11ft', 'not married', 'Nepal']

# %%
mix_fruits = ['guava','mango','apple','pear','fig','orange','banana']
print(mix_fruits)
# Out:
# ['guava', 'mango', 'apple', 'pear', 'fig', 'orange', 'banana']

# %%
len(mix_fruits)
# Out:
# 7

# %%
mix_fruits[0],mix_fruits[3],mix_fruits[-1]
# Out:
# ('guava', 'pear', 'banana')

# %%
mix_fruits.append('pineapple')
print(mix_fruits)
mix_fruits.append('apple')
print(mix_fruits)
# Out:
# ['guava', 'mango', 'pineapple', 'pineapple', 'pineapple', 'pineapple']
# ['guava', 'mango', 'pineapple', 'pineapple', 'pineapple', 'pineapple', 'apple']

# %%
mix_fruits.insert(3,'grapes')
print(mix_fruits)
# Out:
# ['guava', 'mango', 'apple', 'grapes', 'pear', 'fig', 'orange', 'banana']

# %%
mix_fruits[0] = mix_fruits[0].upper()
print(mix_fruits)
# Out:
# ['GUAVA', 'mango', 'apple', 'grapes', 'pear', 'fig', 'orange', 'banana']

# %%
i = '-#-'.join(mix_fruits)
print (i)
# Out:
# GUAVA-#-mango-#-apple-#-grapes-#-pear-#-fig-#-orange-#-banana

# %%
print(mix_fruits.count('apple'))
# Out:
# 1

# %%
mix_fruits.sort()
print(mix_fruits)
# Out:
# ['GUAVA', 'apple', 'banana', 'fig', 'grapes', 'mango', 'orange', 'pear']

# %%
mix_fruits = ['guava','mango','apple','pear','fig','orange','banana']
mix_fruits.reverse()
print(mix_fruits)
# Out:
# ['banana', 'orange', 'fig', 'pear', 'apple', 'mango', 'guava']

# %%
mix_fruits[0:3]
# Out:
# ['banana', 'orange', 'fig']

# %%
mix_fruits[-3:]
# Out:
# ['apple', 'mango', 'guava']

# %%
print(mix_fruits[3])
# Out:
# pear

# %%
mix_fruits.pop(0)
print(mix_fruits)
# Out:
# ['mango', 'guava', 'banana']

# %%
mix_fruits.clear()
print(mix_fruits)
# Out:
# []

# %%
front_end = ['HTMl','CSS','JS','React','Redux']
back_end = ['Node','Express','mangoDB']
front_end.extend(back_end)
print(front_end)
# Out:
# ['HTMl', 'CSS', 'JS', 'React', 'Redux', 'Node', 'Express', 'mangoDB']

# %%
full_stack = ['HTMl', 'CSS', 'JS', 'React', 'Redux', 'Node', 'Express', 'mangoDB']
full_stack.insert(5,'Python')
full_stack.insert(6,'SQL')
print(full_stack)
# Out:
# ['HTMl', 'CSS', 'JS', 'React', 'Redux', 'Python', 'SQL', 'Node', 'Express', 'mangoDB']
